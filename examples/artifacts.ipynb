# %%
import sys
sys.path.append('..')

# %%
import matplotlib.pyplot
import numpy

# %%
phantom = numpy.load('phantom.npy')
matplotlib.pyplot.title('Shepp-Logan Phantom')
matplotlib.pyplot.axis('off')
_ = matplotlib.pyplot.imshow(phantom, cmap='gray')

# %% [markdown]
# ## Add artifatcs with quantization matrix

# %%
import Artifactors.generator
# 0...99
intensity = 10
artifacts = Artifactors.generator.add_artifacts_with_quantization(phantom, intensity)
matplotlib.pyplot.title('Shepp-Logan Phantom (intensity = {})'.format(intensity))
matplotlib.pyplot.axis('off')
_ = matplotlib.pyplot.imshow(artifacts, cmap='gray')

# %%
import Artifactors.generator
# 0...99
intensity = 50
artifacts = Artifactors.generator.add_artifacts_with_quantization(phantom, intensity)
matplotlib.pyplot.title('Shepp-Logan Phantom (intensity = {})'.format(intensity))
matplotlib.pyplot.axis('off')
_ = matplotlib.pyplot.imshow(artifacts, cmap='gray')

# %%
import Artifactors.generator
# 0...99
intensity = 90
artifacts = Artifactors.generator.add_artifacts_with_quantization(phantom, intensity)
matplotlib.pyplot.title('Shepp-Logan Phantom (intensity = {})'.format(intensity))
matplotlib.pyplot.axis('off')
_ = matplotlib.pyplot.imshow(artifacts, cmap='gray')

# %% [markdown]
# ## Add artifatcs with SVD

# %%
import Artifactors.generator
# 0...99
epsilon = 0.1
artifacts = Artifactors.generator.add_artifacts_with_svd(phantom, epsilon)
matplotlib.pyplot.title('Shepp-Logan Phantom (epsilon = {})'.format(epsilon))
matplotlib.pyplot.axis('off')
_ = matplotlib.pyplot.imshow(artifacts, cmap='gray')

# %%
import Artifactors.generator
# 0...99
epsilon = 0.2
artifacts = Artifactors.generator.add_artifacts_with_svd(phantom, epsilon)
matplotlib.pyplot.title('Shepp-Logan Phantom (epsilon = {})'.format(epsilon))
matplotlib.pyplot.axis('off')
_ = matplotlib.pyplot.imshow(artifacts, cmap='gray')

# %%
import Artifactors.generator
# 0...99
epsilon = 0.5
artifacts = Artifactors.generator.add_artifacts_with_svd(phantom, epsilon)
matplotlib.pyplot.title('Shepp-Logan Phantom (epsilon = {})'.format(epsilon))
matplotlib.pyplot.axis('off')
_ = matplotlib.pyplot.imshow(artifacts, cmap='gray')
