# %%
import sys
sys.path.append('..')

# %%
import skimage.data
import matplotlib.pyplot
import numpy

# %%
phantom = matplotlib.pyplot.imread(fname='phantom.png')
matplotlib.pyplot.title('Shepp-Logan Phantom')
matplotlib.pyplot.axis('off')
matplotlib.pyplot.imshow(phantom, cmap='gray')

# %%
# 0...99

import Artifactors.generator

artifacts = Artifactors.generator.add_artifacts_with_quantization(phantom, 99)
matplotlib.pyplot.imshow(artifacts, cmap='gray')

# %%
artifacts = src.utils.add_artifacts_with_svd(phantom, 0.4)
print(artifacts.shape)
matplotlib.pyplot.imshow(artifacts, cmap='gray')
# Out:
# (400, 400)
